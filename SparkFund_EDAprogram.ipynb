# %% [markdown]
# <a href="https://colab.research.google.com/github/Aks2081/Spark-Fund-EDAProject/blob/main/SparkFund_EDAprogram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Formulating the objective function (cost function) - part of statistics
# 1. Analysing the raw data.
# 2. Importing CSV files
# 3. taking info
# 4.basic EDA

# %%
#importing the packages
import numpy as np # numerical libarary
import pandas as pd # data frame libaray
import seaborn as sns # visulization libaray
import matplotlib.pyplot as plt # mathmatical visual libarary - basic libaray

# %% [markdown]
# # importing csv file.

# %%
#df = pd.read_csv('/content/sample_data/companies.txt',sep='\t', encoding='ISO-8895-1' ) # failied due to single ''

# %%
df = pd.read_csv("/content/sample_data/companies.txt", sep='\t', encoding = "ISO-8859-1")

# %%
df
# Out:
#                                                permalink  \
# 0                                    /Organization/-Fame
# 1                                 /Organization/-Qounter
# 2                    /Organization/-The-One-Of-Them-Inc-
# 3                                  /Organization/0-6-Com
# 4                         /Organization/004-Technologies
# ...                                                  ...
# 66363  /Organization/Zznode-Science-And-Technology-Co...
# 66364                          /Organization/Zzzzapp-Com
# 66365                               /Organization/ÃEron
# 66366                             /Organization/ÃAsys-2
# 66367  /Organization/Ä°Novatiff-Reklam-Ve-Tanä±Tä±M-H...
#
#                                                 name  \
# 0                                              #fame
# 1                                           :Qounter
# 2                             (THE) ONE of THEM,Inc.
# 3                                            0-6.com
# 4                                   004 Technologies
# ...                                              ...
# 66363                  ZZNode Science and Technology
# 66364                          Zzzzapp Wireless ltd.
# 66365                                         ÃERON
# 66366                                         Ãasys
# 66367  Ä°novatiff Reklam ve TanÄ±tÄ±m Hizmetleri Tic
#
#                             homepage_url  \
# 0                     http://livfame.com
# 1                 http://www.qounter.com
# 2                    http://oneofthem.jp
# 3                     http://www.0-6.com
# 4      http://004gmbh.de/en/004-interact
# ...                                  ...
# 66363              http://www.zznode.com
# 66364             http://www.zzzzapp.com
# 66365               http://www.aeron.hu/
# 66366               http://www.oasys.io/
# 66367               http://inovatiff.com
#
#                                            category_list     status  \
# 0                                                  Media  operating
# 1      Application Platforms|Real Time|Social Network...  operating
# 2                                      Apps|Games|Mobile  operating
# 3                                            Curated Web  operating
# 4                                               Software  operating
# ...                                                  ...        ...
# 66363                                Enterprise Software  operating
# 66364        Advertising|Mobile|Web Development|Wireless  operating
# 66365                                                NaN  operating
# 66366  Consumer Electronics|Internet of Things|Teleco...  operating
# 66367                 Consumer Goods|E-Commerce|Internet  operating
#
#       country_code state_code                 region           city  \
# 0              IND         16                 Mumbai         Mumbai
# 1              USA         DE             DE - Other  Delaware City
# 2              NaN        NaN                    NaN            NaN
# 3              CHN         22                Beijing        Beijing
# 4              USA         IL  Springfield, Illinois      Champaign
# ...            ...        ...                    ...            ...
# 66363          CHN         22                Beijing        Beijing
# 66364          HRV         15                  Split          Split
# 66365          NaN        NaN                    NaN            NaN
# 66366          USA         CA            SF Bay Area  San Francisco
# 66367          NaN        NaN                    NaN            NaN
#
#        founded_at
# 0             NaN
# 1      04-09-2014
# 2             NaN
# 3      01-01-2007
# 4      01-01-2010
# ...           ...
# 66363         NaN
# 66364  13-05-2012
# 66365  01-01-2011
# 66366  01-01-2014
# 66367         NaN
#
# [66368 rows x 10 columns]

# %% [markdown]
# **Basic EDA** (part of feature engineering)
# # Checking info and dropping **irrelevent** colum
# # checking head and tail values.
# #checking teh shape of df.
# # identifying the missing values
# # removing the duplicates
# # dropping the duplicates
# # describing data set--> decriptive statsics
# # Divide dataset - categorical & numerical colums.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66368 entries, 0 to 66367
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   permalink      66368 non-null  object
#  1   name           66367 non-null  object
#  2   homepage_url   61310 non-null  object
#  3   category_list  63220 non-null  object
#  4   status         66368 non-null  object
#  5   country_code   59410 non-null  object
#  6   state_code     57821 non-null  object
#  7   region         58338 non-null  object
#  8   city           58340 non-null  object
#  9   founded_at     51147 non-null  object
# dtypes: object(10)
# memory usage: 5.1+ MB

# %% [markdown]
# seeing the info - all coloums are object type.
# Coloum number 7, 8 and 9 are not important acording to analysis.

# %%
df.drop(['region', 'city', 'founded_at'], axis=1, inplace=True)

# %%
df.head(10) # checking the 10 head value.
# Out:
#                              permalink                    name  \
# 0                  /Organization/-Fame                   #fame
# 1               /Organization/-Qounter                :Qounter
# 2  /Organization/-The-One-Of-Them-Inc-  (THE) ONE of THEM,Inc.
# 3                /Organization/0-6-Com                 0-6.com
# 4       /Organization/004-Technologies        004 Technologies
# 5     /Organization/01Games-Technology      01Games Technology
# 6  /Organization/0Ndine-Biomedical-Inc  Ondine Biomedical Inc.
# 7                 /Organization/0Xdata                  H2O.ai
# 8                      /Organization/1                One Inc.
# 9            /Organization/1-2-3-Listo             1,2,3 Listo
#
#                         homepage_url  \
# 0                 http://livfame.com
# 1             http://www.qounter.com
# 2                http://oneofthem.jp
# 3                 http://www.0-6.com
# 4  http://004gmbh.de/en/004-interact
# 5             http://www.01games.hk/
# 6               http://ondinebio.com
# 7                     http://h2o.ai/
# 8                 http://whatis1.com
# 9            http://www.123listo.com
#
#                                        category_list     status country_code  \
# 0                                              Media  operating          IND
# 1  Application Platforms|Real Time|Social Network...  operating          USA
# 2                                  Apps|Games|Mobile  operating          NaN
# 3                                        Curated Web  operating          CHN
# 4                                           Software  operating          USA
# 5                                              Games  operating          HKG
# 6                                      Biotechnology  operating          CAN
# 7                                          Analytics  operating          USA
# 8                                             Mobile  operating          USA
# 9                                         E-Commerce  operating          CHL
#
#   state_code
# 0         16
# 1         DE
# 2        NaN
# 3         22
# 4         IL
# 5        NaN
# 6         BC
# 7         CA
# 8         CA
# 9         12

# %%
df.shape # shape is numpy function so no need () function.
# Out:
# (66368, 7)

# %%
df.isnull() # df.isna() both are same -> isnull numpy function- returns true & false.
# Out:
#        permalink   name  homepage_url  category_list  status  country_code  \
# 0          False  False         False          False   False         False
# 1          False  False         False          False   False         False
# 2          False  False         False          False   False          True
# 3          False  False         False          False   False         False
# 4          False  False         False          False   False         False
# ...          ...    ...           ...            ...     ...           ...
# 66363      False  False         False          False   False         False
# 66364      False  False         False          False   False         False
# 66365      False  False         False           True   False          True
# 66366      False  False         False          False   False         False
# 66367      False  False         False          False   False          True
#
#        state_code
# 0           False
# 1           False
# 2            True
# 3           False
# 4           False
# ...           ...
# 66363       False
# 66364       False
# 66365        True
# 66366       False
# 66367        True
#
# [66368 rows x 7 columns]

# %%
df.isnull().sum() # calculates null value in coloum- sum is numpy function
# Either we drop null value or we fill the values.
# Out:
# permalink           0
# name                1
# homepage_url     5058
# category_list    3148
# status              0
# country_code     6958
# state_code       8547
# dtype: int64

# %% [markdown]
# #Now Reading the rounds2 Data
# Importing round2 csv file.

# %%
df1 = pd.read_csv("/content/sample_data/rounds2.csv", encoding = "ISO-8859-1")

# %%
df1
# Out:
#                                         company_permalink  \
# 0                                     /organization/-fame
# 1                                  /ORGANIZATION/-QOUNTER
# 2                                  /organization/-qounter
# 3                     /ORGANIZATION/-THE-ONE-OF-THEM-INC-
# 4                                   /organization/0-6-com
# ...                                                   ...
# 114944                          /organization/zzzzapp-com
# 114945                          /ORGANIZATION/ZZZZAPP-COM
# 114946                               /organization/ãeron
# 114947                             /ORGANIZATION/ÃASYS-2
# 114948  /organization/ä°novatiff-reklam-ve-tanä±tä±m-h...
#
#                                 funding_round_permalink funding_round_type  \
# 0       /funding-round/9a01d05418af9f794eebff7ace91f638            venture
# 1       /funding-round/22dacff496eb7acb2b901dec1dfe5633            venture
# 2       /funding-round/b44fbb94153f6cdef13083530bb48030               seed
# 3       /funding-round/650b8f704416801069bb178a1418776b            venture
# 4       /funding-round/5727accaeaa57461bd22a9bdd945382d            venture
# ...                                                 ...                ...
# 114944  /funding-round/8f6d25b8ee4199e586484d817bceda05   convertible_note
# 114945  /funding-round/ff1aa06ed5da186c84f101549035d4ae               seed
# 114946  /funding-round/59f4dce44723b794f21ded3daed6e4fe            venture
# 114947  /funding-round/35f09d0794651719b02bbfd859ba9ff5               seed
# 114948  /funding-round/af942869878d2cd788ef5189b435ebc4              grant
#
#        funding_round_code   funded_at  raised_amount_usd
# 0                       B  05-01-2015         10000000.0
# 1                       A  14-10-2014                NaN
# 2                     NaN  01-03-2014           700000.0
# 3                       B  30-01-2014          3406878.0
# 4                       A  19-03-2008          2000000.0
# ...                   ...         ...                ...
# 114944                NaN  01-03-2014            41313.0
# 114945                NaN  01-05-2013            32842.0
# 114946                  A  01-08-2014                NaN
# 114947                NaN  01-01-2015            18192.0
# 114948                NaN  01-10-2013            14851.0
#
# [114949 rows x 6 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114949 entries, 0 to 114948
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   company_permalink        114949 non-null  object
#  1   funding_round_permalink  114949 non-null  object
#  2   funding_round_type       114949 non-null  object
#  3   funding_round_code       31140 non-null   object
#  4   funded_at                114949 non-null  object
#  5   raised_amount_usd        94959 non-null   float64
# dtypes: float64(1), object(5)
# memory usage: 5.3+ MB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66368 entries, 0 to 66367
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   permalink      66368 non-null  object
#  1   name           66367 non-null  object
#  2   homepage_url   61310 non-null  object
#  3   category_list  63220 non-null  object
#  4   status         66368 non-null  object
#  5   country_code   59410 non-null  object
#  6   state_code     57821 non-null  object
# dtypes: object(7)
# memory usage: 3.5+ MB

# %% [markdown]
# #df and df1 - companies are common (permalink ) now we will take difference of total count.

# %% [markdown]
# #analyzing df1 & df- finding out the primary coloum.

# %%
df1.duplicated().sum() # zero count means no duplicate
# Out:
# 0

# %%
df.duplicated(). sum() # zero count means no duplicate
# Out:
# 0

# %%
df1.describe() # raised amount data generated as this is only numerical coloum. rest object.
# Out:
#        raised_amount_usd
# count       9.495900e+04
# mean        1.042687e+07
# std         1.148212e+08
# min         0.000000e+00
# 25%         3.225000e+05
# 50%         1.680511e+06
# 75%         7.000000e+06
# max         2.127194e+10

# %%
df1.shape # shape is numpy function so no need () function.
# Out:
# (114949, 6)

# %% [markdown]
# # steps to clean-
# 1. encode df Company_permalink coloum in ASCII value.
# 2. encode df1 permalink coloum in ASCII value.
# 3. Convert either in lower case or upper case string values of
#    Company_permalink & permalink
# 4.Count the unique value in Company_permalink & permalink, if found to be equal then be merged two coloum.
# #How to merge-
# 1. Covert Permalink & company_permalink in a set
# 2. Do the subset of small set than drop the small subset.
# 3. merge all the data accordinge to new subset in a master data frame.
